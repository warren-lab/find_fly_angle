# %%
pwd
# Out:
# '/Users/tim/python_packages/find_fly_angle/examples'

# %%
run run_example.py ~/Downloads/sample_images
# Out:
# 0/551: image-0000.png, angle: 134.75
# 1/551: image-0001.png, angle: 135.26
# 2/551: image-0002.png, angle: 138.93
# 3/551: image-0003.png, angle: 142.11
# 4/551: image-0004.png, angle: 140.94
# 5/551: image-0005.png, angle: 139.75
# 6/551: image-0006.png, angle: 139.91
# 7/551: image-0007.png, angle: 140.04
# 8/551: image-0008.png, angle: 139.87
# 9/551: image-0009.png, angle: 141.34

# %%
perim_1_list
# Out:
# [367.66399443149567,
#  364.0071402788162,
#  356.69343197345734,
#  360.3502861261368,
#  358.1076455116272,
#  361.76449966430664,
#  362.59292674064636,
#  365.4213538169861,
#  370.14927566051483,
#  352.9360725879669]

# %%
perim_0_list
# Out:
# [391.26197350025177,
#  4.0,
#  377.5634891986847,
#  2.8284270763397217,
#  2.8284270763397217,
#  394.534051656723,
#  0.0,
#  6.0,
#  8.242640614509583,
#  386.04877042770386]
