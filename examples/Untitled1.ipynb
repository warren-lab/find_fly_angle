# %%
run run_example.py ~/Downloads/sample_images
# Out:
# 0/551: image-0000.png, angle: 134.75
# 1/551: image-0001.png, angle: 135.26
# 2/551: image-0002.png, angle: 138.93
# 3/551: image-0003.png, angle: 142.11
# 4/551: image-0004.png, angle: 140.94
# 5/551: image-0005.png, angle: 139.75
# 6/551: image-0006.png, angle: 139.91
# 7/551: image-0007.png, angle: 140.04
# 8/551: image-0008.png, angle: 139.87
# 9/551: image-0009.png, angle: 141.34
# 10/551: image-0010.png, angle: 143.13
# 11/551: image-0011.png, angle: 144.00
# 12/551: image-0012.png, angle: 145.02
# 13/551: image-0013.png, angle: 144.45
# 14/551: image-0014.png, angle: 143.60
# 15/551: image-0015.png, angle: 144.36
# 16/551: image-0016.png, angle: 144.95
# 17/551: image-0017.png, angle: 145.05
# 18/551: image-0018.png, angle: 145.81
# 19/551: image-0019.png, angle: 148.06
# 20/551: image-0020.png, angle: 147.43
# 21/551: image-0021.png, angle: 145.57
# 22/551: image-0022.png, angle: 143.91
# 23/551: image-0023.png, angle: 142.03
# 24/551: image-0024.png, angle: 139.64
# ...

# %%
perim_1_list
# Out:
# [367.66399443149567,
#  364.0071402788162,
#  356.69343197345734,
#  360.3502861261368,
#  358.1076455116272,
#  361.76449966430664,
#  362.59292674064636,
#  365.4213538169861,
#  370.14927566051483,
#  352.9360725879669]

# %%
perim_0_list
# Out:
# [391.26197350025177,
#  389.11983811855316,
#  377.5634891986847,
#  394.19090580940247,
#  386.3919162750244,
#  394.534051656723,
#  395.0193328857422,
#  401.26197350025177,
#  400.43354642391205,
#  386.04877042770386]

# %%
plt.scatter(discrim_list,perimeter_discrim_list)
